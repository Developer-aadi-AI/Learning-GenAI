# %%
import os
from dotenv import load_dotenv

load_dotenv()

OPENAI_API_KEY = os.environ.get("OPENAI_API_KEY")

if OPENAI_API_KEY:
    print("OpenAI API key loaded Successfully")
else:
    print("Warning: No OpenAI API key found. Please set it in your .env file.")
# Out:
# Warning: No OpenAI API key found. Please set it in your .env file.

# %%
# Order records
ORDERS_DB = {
    "ORD-1001":{
        "customer":"Alice Johnson",
        "product": "Laptop Pro 15",
        "price":1299.99,
        "status":"delivered",
        "delivery_date":"2026-02-05",
    },
    "ORD-1002":{
        "customer":"Bob Smith",
        "product": "Laptop Pro 15",
        "price":1299.99,
        "status":"delivered",
        "delivery_date":"2026-02-05",
    },
    "ORD-1001":{
        "customer":"Alice Johnson",
        "product": "Laptop Pro 15",
        "price":1299.99,
        "status":"delivered",
        "delivery_date":"2026-02-05",
    },
}
